# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
import netCDF4 as nc
import xarray as xr
import scipy.ndimage
import scipy as sp
import alphashape
import glob
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
from matplotlib import style
style.use('ggplot') or plt.style.use('ggplot')

# %%
# Read in the grounded area csv files

sims = ['Flux100Sigma4000', 'Flux100Sigma8000', 'Flux100Sigma16000', 'Flux200Sigma4000',  \
        'Flux200Sigma8000', 'Flux300Sigma4000', 'Flux300Sigma8000',  'Flux300Sigma12000', \
        'Flux400Sigma4000', 'Flux400Sigma8000', 'Flux500Sigma4000',  'Flux500Sigma8000',  \
        'Flux500Sigma12000']
dfs = {}
for sim in sims:
    dfs[sim] = pd.read_csv('../Data/GroundedMask/' + str(sim) + '.csv')

# %%
# Find the maximum grounded width for each simulation

miny = {}
maxy = {}
GroundedWidths = {}
dfs_GL = {}
for sim in sims:
    dfs_GL[sim] = dfs[sim][dfs[sim]['groundedmask'] == 0]
    miny[sim] = dfs_GL[sim]['Points:1'].min()
    maxy[sim] = dfs_GL[sim]['Points:1'].max()
    GroundedWidths[sim] = maxy[sim] - miny[sim]
GroundedWidths
# Out:
# {'Flux100Sigma4000': 7364.8,
#  'Flux100Sigma8000': 15584.5,
#  'Flux100Sigma16000': 32120.0,
#  'Flux200Sigma4000': 7019.0,
#  'Flux200Sigma8000': 16130.6,
#  'Flux300Sigma4000': 7266.799999999999,
#  'Flux300Sigma8000': 16042.7,
#  'Flux300Sigma12000': 24629.0,
#  'Flux400Sigma4000': 8067.200000000001,
#  'Flux400Sigma8000': 16042.7,
#  'Flux500Sigma4000': 8067.200000000001,
#  'Flux500Sigma8000': 16042.7,
#  'Flux500Sigma12000': 24341.0}

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

ax.scatter(100, GroundedWidths[sims[0]], label = r'$\sigma = 4000$')
ax.scatter(100, GroundedWidths[sims[1]], label = r'$\sigma = 8000$')
ax.scatter(100, GroundedWidths[sims[2]], label = r'$\sigma = 16000$')
ax.scatter(200, GroundedWidths[sims[3]], label = r'$\sigma = 4000$')
ax.scatter(200, GroundedWidths[sims[4]], label = r'$\sigma = 8000$')
ax.scatter(300, GroundedWidths[sims[5]], label = r'$\sigma = 4000$')
ax.scatter(300, GroundedWidths[sims[6]], label = r'$\sigma = 8000$')
ax.scatter(300, GroundedWidths[sims[7]], label = r'$\sigma = 12000$')
ax.scatter(400, GroundedWidths[sims[8]], label = r'$\sigma = 4000$')
ax.scatter(400, GroundedWidths[sims[9]], label = r'$\sigma = 8000$')
ax.scatter(500, GroundedWidths[sims[10]], label = r'$\sigma = 4000$')
ax.scatter(500, GroundedWidths[sims[11]], label = r'$\sigma = 8000$')
ax.scatter(500, GroundedWidths[sims[12]], label = r'$\sigma = 12000$')
ax.legend(fontsize='12')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

ax.scatter(4000, GroundedWidths[sims[0]])
ax.scatter(8000, GroundedWidths[sims[1]])
ax.scatter(16000, GroundedWidths[sims[2]])
ax.scatter(4000, GroundedWidths[sims[3]])
ax.scatter(8000, GroundedWidths[sims[4]])
ax.scatter(4000, GroundedWidths[sims[5]])
ax.scatter(8000, GroundedWidths[sims[6]])
ax.scatter(12000, GroundedWidths[sims[7]])
ax.scatter(4000, GroundedWidths[sims[8]])
ax.scatter(8000, GroundedWidths[sims[9]])
ax.scatter(4000, GroundedWidths[sims[10]])
ax.scatter(8000, GroundedWidths[sims[11]])
ax.scatter(12000, GroundedWidths[sims[12]])
